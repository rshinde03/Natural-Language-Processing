# %% [markdown]
# ## NER & De-Identification Using SPACY
# ### By RUTUJA SHINDE

# %%
import spacy

# %%
import en_core_web_sm

# %%
nlp = en_core_web_sm.load()

# %%
from spacy import displacy

# %% [markdown]
# ## WebScarpping of News Data

# %%
import bs4 as bs                                                           # BeautifulSoup
import urllib.request
import re

# %%
def _scrape_webpage(url):
       
    scraped_textdata = urllib.request.urlopen(url)
    textdata = scraped_textdata.read()
    parsed_textdata = bs.BeautifulSoup(textdata,'lxml')
    paragraphs = parsed_textdata.find_all('p')
    formated_text = ""

    for para in paragraphs:
        formated_text += para.text
    
    return formated_text

# %%
mytext = _scrape_webpage('https://www.nytimes.com/2020/03/31/world/coronavirus-live-news-updates.html?action=click&module=Spotlight&pgtype=Homepage')

# %%
len(mytext)                                                                #length of the web scrapped data
# Out:
# 49391

# %% [markdown]
# ## NER Using SPACY

# %%
webtext=nlp(mytext)
print(mytext[:1500])                                                #display the first 1500 words of document
# Out:
# AdvertisementSupported byThe scientists leading the administration’s fight estimated the virus could kill between 100,000 and 240,000 Americans. New data suggests many as 25 percent of infected people may not show symptoms.This briefing has ended. Read our global live coverage on the coronavirus pandemic here.The top government scientists battling the coronavirus estimated Tuesday that the deadly pathogen could kill between 100,000 and 240,000 Americans, in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. Anthony S. Fauci, the nation’s leading infectious disease expert, and Dr. Deborah L. Birx, who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. Fauci and Dr. Birx said the number of deaths could be much higher if Americans do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President Trump, who on Sunday extended for 30 days the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. Fauci and Dr. Birx convinced him that the death toll would be even hi

# %%
len(webtext.ents)                             #number of entities in the article
# Out:
# 592

# %%
for ent in webtext.ents: 
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# between 100,000 and 240,000 106 133 CARDINAL
# Americans 134 143 NORP
# 25 percent 171 181 PERCENT
# Tuesday 376 383 DATE
# between 100,000 and 240,000 420 447 CARDINAL
# Americans 448 457 NORP
# Anthony S. Fauci 613 629 PERSON
# Deborah L. Birx 687 702 PERSON
# the White House 784 799 FAC
# Tuesday 803 810 DATE
# Fauci 1059 1064 PERSON
# Birx 1073 1077 PERSON
# Americans 1128 1137 NORP
# Trump 1275 1280 PERSON
# Sunday 1289 1295 DATE
# 30 days 1309 1316 DATE
# Fauci 1431 1436 PERSON
# Birx 1445 1449 PERSON
# Americans 1597 1606 NORP
# Tuesday 1628 1635 DATE
# first 1644 1649 ORDINAL
# Trump 1664 1669 PERSON
# the past several weeks 1823 1845 DATE
# Birx 1851 1855 PERSON
# Fauci 1864 1869 PERSON
# Tuesday afternoon 2030 2047 TIME
# at least 173,741 2049 2065 CARDINAL
# Washington 2098 2108 GPE
# D.C. 2110 2114 GPE
# four 2120 2124 CARDINAL
# U.S. 2125 2129 GPE
# New York Times 2194 2208 ORG
# At least 3,433 2219 2233 CARDINAL
# recent days 18605 18616 DATE
# Japan 18618 18623 GPE
# Europe 18657 18663 LOC
# the United States 18736 18753 GPE
# South Korea 18755 18766 GPE
# 14 days 18867 18874 DATE
# China 18891 18896 GPE
# Chinese 18956 18963 NORP
# Singapore 19026 19035 GPE
# each day 19124 19132 DATE
# Taiwan 19198 19204 GPE
# Southeast Asia 19232 19246 LOC
# 33,000 19258 19264 MONEY
# Kristi Govella 19476 19490 PERSON
# Asian 19518 19523 NORP
# the University of Hawaii, Manoa 19535 19566 ORG
# British 19723 19730 NORP
# the Intensive Care Society 19966 19992 ORG
# Tuesday 20002 20009 DATE
# night 20010 20015 TIME
# British 20047 20054 NORP
# Italy 20246 20251 GPE
# This week 20330 20339 DATE
# London 20349 20355 GPE
# the Coronavirus Act 20856 20875 LAW
# The Intensive Care Society 21094 21120 ORG
# Chris 21324 21329 PERSON
# this morning 21370 21382 TIME
# this morning 21686 21698 TIME
# Chris 21779 21784 PERSON
# Chris 21804 21809 PERSON
# 9 o’clock 21835 21844 TIME
# CNN 21848 21851 ORG
# one 21870 21873 CARDINAL
# Chris 22166 22171 PERSON
# Chris 22197 22202 PERSON
# New York City 22588 22601 GPE
# Yolanda Encanción 22933 22950 PERSON
# Bronx 23021 23026 GPE
# fewer than 1 million 23106 23126 CARDINAL
# more than five million 23145 23167 CARDINAL
# New York Times 23182 23196 ORG
# M.T.A. 23209 23215 GPE
# Manhattan 23345 23354 GPE
# Bronx 23435 23440 GPE
# Andrew Cuomo 23878 23890 PERSON
# New York 23925 23933 GPE
# 9,298 23947 23952 CARDINAL
# 75,795 23986 23992 CARDINAL
# Tuesday 24009 24016 DATE
# New York City 24021 24034 GPE
# 43,139 24036 24042 CARDINAL
# 10,900 24117 24123 CARDINAL
# 15 percent 24128 24138 PERCENT
# yesterday 24144 24153 DATE
# 2,710 24165 24170 CARDINAL
# More than 18,000 24226 24242 CARDINAL
# overnight 24262 24271 TIME
# about 205,000 24318 24331 CARDINAL
# more than 1 percent 24333 24352 PERCENT
# population.transcript“You 24368 24393 ORG
# one 24413 24416 CARDINAL
# today 24513 24518 DATE
# two hours later 24560 24575 TIME
# CNA 24656 24659 ORG
# One 24911 24914 CARDINAL
# 19 24942 24944 CARDINAL
# Palo Alto 24972 24981 GPE
# New Orleans 24993 25004 GPE
# DuPage County 25017 25030 GPE
# Sacramento County 25038 25055 GPE
# Northern California 25167 25186 LOC
# Assist 25398 25404 NORP
# Turning 25453 25460 WORK_OF_ART
# N95 26757 26760 ORG
# N95 26901 26904 ORG
# Ziploc 27090 27096 GPE
# the next day 27105 27117 DATE
# U.S. 27679 27683 GPE
# less than $30,000 27706 27723 MONEY
# first 27869 27874 ORDINAL
# second 27898 27904 ORDINAL
# 16 hours 27917 27925 TIME
# two 28026 28029 CARDINAL
# less than $30,000 28654 28671 MONEY
# second 28732 28738 ORDINAL
# third 28748 28753 ORDINAL
# Jeffrey Ravago 28831 28845 PERSON
# Vallejo 28880 28887 GPE
# Calif. 28889 28895 GPE
# Cynthia Yee 28945 28956 PERSON
# San Francisco 28989 29002 GPE
# one 29041 29044 CARDINAL
# N95 29045 29048 ORG
# the past few weeks 45488 45506 DATE
# ’ve 45614 45617 CARDINAL
# Americans 45950 45959 NORP
# W.H.O. 46173 46179 ORG
# the United States 47191 47208 GPE
# China 47210 47215 GPE
# Europe 47220 47226 LOC
# American 47232 47240 NORP
# at least 12 to 18 months 47314 47338 DATE
# two weeks 48304 48313 DATE
# six feet 48591 48599 QUANTITY
# a year 49038 49044 DATE
# the next five years 49101 49120 DATE

# %%
dict([(str(x),x.label_)for x in webtext.ents])          #all named entities of document and put in dictioanry
# Out:
# {'between 100,000 and 240,000': 'CARDINAL',
#  'Americans': 'NORP',
#  '25 percent': 'PERCENT',
#  'Tuesday': 'DATE',
#  'Anthony S. Fauci': 'PERSON',
#  'Deborah L. Birx': 'PERSON',
#  'the White House': 'ORG',
#  'Fauci': 'PERSON',
#  'Birx': 'PERSON',
#  'Trump': 'PERSON',
#  'Sunday': 'DATE',
#  '30 days': 'DATE',
#  'first': 'ORDINAL',
#  'the past several weeks': 'DATE',
#  'Tuesday afternoon': 'TIME',
#  'at least 173,741': 'CARDINAL',
#  'Washington': 'GPE',
#  'D.C.': 'GPE',
#  'four': 'CARDINAL',
#  'U.S.': 'GPE',
#  'New York Times': 'ORG',
#  'At least 3,433': 'CARDINAL',
#  'American': 'NORP',
#  'two weeks': 'DATE',
#  'Italy': 'GPE',
#  'New York': 'GPE',
#  'the next several days to a week or so': 'DATE',
#  '100,000 to 200,000': 'CARDINAL',
#  '100 percent': 'PERCENT',
#  'daily': 'DATE',
#  'White House': 'ORG',
#  'few weeks': 'DATE',
#  'three': 'CARDINAL',
#  'another month': 'DATE',
#  'the United States': 'GPE',
#  'larger than 10': 'CARDINAL',
#  'Anthony Fauci': 'PERSON',
#  'the National Institute of Allergy and Infectious Diseases': 'ORG',
#  '15 days': 'DATE',
#  'weeks': 'DATE',
#  'mid-April': 'DATE',
#  'as many as 2.2 million': 'CARDINAL',
#  '100,000': 'CARDINAL',
#  'weeks earlier': 'DATE',
#  'mid-March': 'DATE',
#  'almost two months': 'DATE',
#  'recent weeks': 'DATE',
#  'the Centers for Disease Control and Prevention': 'ORG',
#  'Robert Redfield': 'PERSON',
#  'National Public Radio': 'ORG',
#  'a couple of days': 'DATE',
#  'Redfield': 'PERSON',
#  'December': 'DATE',
#  'Guangdong': 'GPE',
#  'China': 'GPE',
#  'Wuhan': 'GPE',
#  'February': 'DATE',
#  'Day 7': 'DATE',
#  'Day 10 or 11.Already by Day 7': 'DATE',
#  'as many as 18 percent': 'PERCENT',
#  'one': 'CARDINAL',
#  'Hong Kong': 'GPE',
#  '20 to 40 percent': 'PERCENT',
#  'influenza': 'ORG',
#  'New York State': 'GPE',
#  'at least 1,550': 'CARDINAL',
#  'Andrew M. Cuomo': 'PERSON',
#  'eBay': 'ORG',
#  '50': 'CARDINAL',
#  'Cuomo': 'PERSON',
#  'Democrat': 'NORP',
#  'Larry Hogan': 'PERSON',
#  'Maryland': 'GPE',
#  'NPR': 'ORG',
#  'Hogan': 'PERSON',
#  'Republican': 'NORP',
#  'America': 'GPE',
#  'Gretchen Whitmer': 'PERSON',
#  'Michigan': 'GPE',
#  'the Navajo Nation': 'ORG',
#  'about nine': 'CARDINAL',
#  '10': 'CARDINAL',
#  'María José Rodríguez': 'GPE',
#  'Spain': 'GPE',
#  'hours': 'TIME',
#  'more than two weeks': 'DATE',
#  'Igualada': 'GPE',
#  'Rodríguez': 'PERSON',
#  '63': 'DATE',
#  'La Pobla de Claramunt': 'ORG',
#  'European': 'NORP',
#  '30 miles': 'QUANTITY',
#  'Barcelona': 'GPE',
#  'nearly 20,000': 'CARDINAL',
#  'more than 2,500': 'CARDINAL',
#  'midnight': 'TIME',
#  'March 12': 'DATE',
#  'about 65,000': 'CARDINAL',
#  'Gemma Sabaté': 'PERSON',
#  'the hundreds of thousands': 'MONEY',
#  'Los Angeles': 'GPE',
#  'Fort Lauderdale': 'GPE',
#  'Phoenix': 'GPE',
#  'Minnesota': 'GPE',
#  'GoFundMe': 'ORG',
#  'Instagram': 'NORP',
#  'two': 'CARDINAL',
#  'Today': 'DATE',
#  'one week earlier this month': 'DATE',
#  '3.3 million': 'CARDINAL',
#  'Alice Fothergill': 'PERSON',
#  'the University of Vermont': 'ORG',
#  'thousands': 'CARDINAL',
#  'Las Vegas': 'GPE',
#  'The City of Las Vegas': 'GPE',
#  'Clarke County': 'GPE',
#  'Catholic Charities': 'ORG',
#  'Touro University': 'ORG',
#  'April 3': 'DATE',
#  'More than 6,500': 'CARDINAL',
#  'nearly 70 percent': 'PERCENT',
#  'Cashman Center': 'FAC',
#  'about seven miles': 'QUANTITY',
#  'the Las Vegas Strip': 'GPE',
#  '24,000 square feet': 'QUANTITY',
#  'six feet': 'QUANTITY',
#  'social distancing protocols': 'ORG',
#  'David Riggleman': 'PERSON',
#  'the City of Las Vegas': 'GPE',
#  'Riggleman': 'PERSON',
#  'day': 'DATE',
#  'the past decade': 'DATE',
#  'trillions of dollars': 'MONEY',
#  'Carlos Hernandez': 'PERSON',
#  'JPMorgan Chase': 'ORG',
#  '2008': 'DATE',
#  'Hernandez': 'PERSON',
#  'Congress': 'ORG',
#  'United States': 'GPE',
#  'the Federal Reserve': 'ORG',
#  'Asia': 'LOC',
#  'Europe': 'LOC',
#  'Singapore': 'GPE',
#  'Taiwan': 'GPE',
#  'recent days': 'DATE',
#  'Japan': 'GPE',
#  'South Korea': 'GPE',
#  '14 days': 'DATE',
#  'Chinese': 'NORP',
#  'each day': 'DATE',
#  'Southeast Asia': 'LOC',
#  '33,000': 'MONEY',
#  'Kristi Govella': 'PERSON',
#  'Asian': 'NORP',
#  'the University of Hawaii, Manoa': 'ORG',
#  'British': 'NORP',
#  'the Intensive Care Society': 'ORG',
#  'night': 'TIME',
#  'This week': 'DATE',
#  'London': 'GPE',
#  'the Coronavirus Act': 'LAW',
#  'The Intensive Care Society': 'ORG',
#  'Chris': 'PERSON',
#  'this morning': 'TIME',
#  '9 o’clock': 'TIME',
#  'CNN': 'ORG',
#  'New York City': 'GPE',
#  'Yolanda Encanción': 'PERSON',
#  'Bronx': 'GPE',
#  'fewer than 1 million': 'CARDINAL',
#  'more than five million': 'CARDINAL',
#  'M.T.A.': 'GPE',
#  'Manhattan': 'GPE',
#  'Andrew Cuomo': 'PERSON',
#  '9,298': 'CARDINAL',
#  '75,795': 'CARDINAL',
#  '43,139': 'CARDINAL',
#  '10,900': 'CARDINAL',
#  '15 percent': 'PERCENT',
#  'yesterday': 'DATE',
#  '2,710': 'CARDINAL',
#  'More than 18,000': 'CARDINAL',
#  'overnight': 'TIME',
#  'about 205,000': 'CARDINAL',
#  'more than 1 percent': 'PERCENT',
#  'population.transcript“You': 'ORG',
#  'today': 'DATE',
#  'two hours later': 'TIME',
#  'CNA': 'ORG',
#  'One': 'CARDINAL',
#  '19': 'CARDINAL',
#  'Palo Alto': 'GPE',
#  'New Orleans': 'GPE',
#  'DuPage County': 'GPE',
#  'Sacramento County': 'GPE',
#  'Northern California': 'LOC',
#  'Assist': 'NORP',
#  'Turning': 'WORK_OF_ART',
#  'N95': 'ORG',
#  'Ziploc': 'GPE',
#  'the next day': 'DATE',
#  'less than $30,000': 'MONEY',
#  'second': 'ORDINAL',
#  '16 hours': 'TIME',
#  'third': 'ORDINAL',
#  'Jeffrey Ravago': 'PERSON',
#  'Vallejo': 'GPE',
#  'Calif.': 'GPE',
#  'Cynthia Yee': 'PERSON',
#  'San Francisco': 'GPE',
#  'Korean': 'NORP',
#  'the Defense Production Act': 'LAW',
#  'hundreds of thousands': 'CARDINAL',
#  'earlier this month': 'DATE',
#  'a hundred thousand': 'CARDINAL',
#  'Larry Hall': 'PERSON',
#  'August': 'DATE',
#  'the Federal Emergency Management Agency': 'ORG',
#  'Afghans': 'NORP',
#  'decades': 'DATE',
#  'Afghanistan': 'GPE',
#  '40': 'CARDINAL',
#  'the month': 'DATE',
#  'one day': 'DATE',
#  'more than $100,000.Mohamed Kareem Tawain': 'MONEY',
#  'Herat': 'GPE',
#  'Russia': 'GPE',
#  'Vladimir V. Putin': 'PERSON',
#  'last week': 'DATE',
#  'Denis Protsenko': 'ORG',
#  'Hospital No. 40': 'ORG',
#  'Moscow': 'GPE',
#  'Facebook': 'ORG',
#  'Putin': 'PERSON',
#  'last Tuesday': 'DATE',
#  'Protsenko': 'PERSON',
#  'Kremlin': 'ORG',
#  'Dmitry Peskov': 'PERSON',
#  'Interfax': 'NORP',
#  '500': 'CARDINAL',
#  '2,337': 'CARDINAL',
#  'a week ago': 'DATE',
#  '17': 'CARDINAL',
#  'the European Union': 'ORG',
#  'Germany': 'GPE',
#  'Christine Lambrecht': 'PERSON',
#  'Deutschlandfunk': 'GPE',
#  'Poland': 'GPE',
#  'an estimated 10,000': 'CARDINAL',
#  'Croatia': 'GPE',
#  'Germans': 'NORP',
#  'More than a year': 'DATE',
#  'France': 'GPE',
#  'Britain': 'GPE',
#  'Iran': 'GPE',
#  'Instex': 'ORG',
#  'Iranian': 'NORP',
#  'The United States': 'GPE',
#  '2018': 'DATE',
#  '2015': 'DATE',
#  'secondary': 'ORDINAL',
#  'January 2019': 'DATE',
#  'Europeans': 'NORP',
#  'This month': 'DATE',
#  '5 million': 'CARDINAL',
#  'nearly $5.5 million': 'MONEY',
#  '41,495': 'CARDINAL',
#  '2,757': 'CARDINAL',
#  'more than a dozen': 'CARDINAL',
#  'Pennsylvania': 'GPE',
#  'the end of the day': 'DATE',
#  'Two': 'CARDINAL',
#  'two or three': 'CARDINAL',
#  'more than 50': 'CARDINAL',
#  'the night': 'TIME',
#  '60': 'CARDINAL',
#  'Vic Walczak': 'PERSON',
#  'the American Civil Liberties Union': 'ORG',
#  'Nigeria': 'GPE',
#  'Indonesia': 'GPE',
#  'Guatemala': 'GPE',
#  'India': 'GPE',
#  'John E. Jones III': 'PERSON',
#  'the Federal District Court': 'ORG',
#  'the Middle District': 'LOC',
#  'Kenya': 'PERSON',
#  'Yasin Moyo': 'PERSON',
#  'Monday night': 'TIME',
#  'Nairobi': 'GPE',
#  'East African': 'NORP',
#  'Friday': 'DATE',
#  'Hours': 'TIME',
#  'Mombasa': 'GPE',
#  'Independent Police Oversight Authority': 'ORG',
#  'The 7 p.m. to 5 a.m.': 'TIME',
#  '59': 'CARDINAL',
#  'at least one': 'CARDINAL',
#  'Jonathan Sumption': 'PERSON',
#  'Supreme Court': 'ORG',
#  'BBC': 'ORG',
#  'Monday': 'DATE',
#  'more than a quarter': 'CARDINAL',
#  'Interior Ministry': 'ORG',
#  'up to 3,000': 'CARDINAL',
#  'about $3,300.Former': 'MONEY',
#  'Joseph R. Biden Jr.': 'PERSON',
#  'Bernie Sanders': 'PERSON',
#  'Vermont': 'GPE',
#  'Sanders': 'PERSON',
#  'Medicare': 'ORG',
#  'Biden': 'PERSON',
#  'Democratic': 'NORP',
#  'as many as 200,000': 'CARDINAL',
#  '3,305': 'CARDINAL',
#  'more than 20,000': 'CARDINAL',
#  'at least 3,430': 'CARDINAL',
#  'late Tuesday': 'TIME',
#  'morning': 'TIME',
#  'North Korea': 'GPE',
#  'more than 1,500': 'CARDINAL',
#  'nearly two weeks': 'DATE',
#  'zero': 'CARDINAL',
#  '1,541': 'CARDINAL',
#  'National Health Commission': 'ORG',
#  'the World Health Organization': 'ORG',
#  'antsy teenagers': 'PERSON',
#  'Cara Buckley': 'PERSON',
#  'David D. Kirkpatrick': 'PERSON',
#  'Michael Cooper': 'PERSON',
#  'Alan Blinder': 'PERSON',
#  'Apoorva Mandavilli': 'PERSON',
#  'Emma Cott': 'PERSON',
#  'Karen Zraick': 'PERSON',
#  'Michael D. Shear': 'PERSON',
#  'Michael Crowley': 'PERSON',
#  'James Glanz': 'PERSON',
#  'Dan Levin': 'PERSON',
#  'Corina Knoll': 'PERSON',
#  'Caitlin Dickerson': 'PERSON',
#  'Elisabetta Povoledo': 'PERSON',
#  'Mujib Mashal': 'PERSON',
#  'Asadullah Timory': 'PERSON',
#  'Najim Rahim': 'PERSON',
#  'Aurelien Breeden': 'PERSON',
#  'Constant Méheut': 'PERSON',
#  'Selam Gebrekidan': 'PERSON',
#  'Marc Santora': 'PERSON',
#  'Megan Specia': 'ORG',
#  'Joanna Berendt': 'PERSON',
#  'Benjamin Novak': 'PERSON',
#  'Sarah Mervosh': 'PERSON',
#  'Katie Rogers': 'PERSON',
#  'Raphael Minder': 'PERSON',
#  'Elian Peltier': 'PERSON',
#  'Steven Erlanger': 'PERSON',
#  'Iliana Magra': 'PERSON',
#  'Donald G. McNeil Jr.': 'PERSON',
#  'Anna Schaverien': 'PERSON',
#  'Maria Abi-Habib': 'PERSON',
#  'Yasir': 'PERSON',
#  'Raymond Zhong': 'PERSON',
#  'Knvul Sheikh': 'PERSON',
#  'Melissa Eddy': 'PERSON',
#  'Choe Sang-Hun': 'PERSON',
#  'Abdi Latif Dahir': 'WORK_OF_ART',
#  'Michael M. Grynbaum': 'PERSON',
#  'Andy Newman': 'PERSON',
#  'Katie Glueck': 'PERSON',
#  'Helene Cooper': 'PERSON',
#  'Kate Kelly': 'PERSON',
#  'Peter Eavis': 'PERSON',
#  'Thomas Gibbons-Neff': 'PERSON',
#  'Andrew Higgins': 'PERSON',
#  'Hassan': 'PERSON',
#  'Richard C. Paddock': 'PERSON',
#  'April 11': 'DATE',
#  '2020This': 'PERSON',
#  'American Enterprise Institute': 'ORG',
#  'Scott Gottlieb': 'PERSON',
#  'Caitlin Rivers': 'PERSON',
#  'Mark B. McClellan': 'PERSON',
#  'Lauren Silvis': 'PERSON',
#  'Crystal Watson': 'PERSON',
#  'at least 14 days': 'DATE',
#  'Charity Navigator': 'ORG',
#  'the American Red Cross': 'ORG',
#  'World Central Kitchen': 'ORG',
#  'More than 30,000': 'CARDINAL',
#  'the past few weeks': 'DATE',
#  '’ve': 'CARDINAL',
#  'W.H.O.': 'ORG',
#  'at least 12 to 18 months': 'DATE',
#  'a year': 'DATE',
#  'the next five years': 'DATE'}

# %%
from collections import Counter

# %%
labels = [x.label_ for x in webtext.ents]                               #count each named entity in the document
Counter(labels)
# Out:
# Counter({'CARDINAL': 75,
#          'NORP': 44,
#          'PERCENT': 7,
#          'DATE': 86,
#          'PERSON': 135,
#          'FAC': 2,
#          'ORDINAL': 11,
#          'TIME': 18,
#          'GPE': 130,
#          'ORG': 56,
#          'QUANTITY': 5,
#          'MONEY': 8,
#          'LOC': 10,
#          'LAW': 3,
#          'WORK_OF_ART': 2})

# %%
items=[x.text for x in webtext.ents]         # 30 most frequent named entities in the document
Counter(items).most_common(30)
# Out:
# [('Trump', 22),
#  ('Tuesday', 18),
#  ('China', 13),
#  ('Americans', 10),
#  ('American', 10),
#  ('the United States', 9),
#  ('first', 7),
#  ('one', 7),
#  ('Iran', 7),
#  ('Europe', 6),
#  ('U.S.', 5),
#  ('two weeks', 5),
#  ('European', 5),
#  ('Chris', 5),
#  ('Fauci', 4),
#  ('four', 4),
#  ('Italy', 4),
#  ('Germany', 4),
#  ('Birx', 3),
#  ('daily', 3),
#  ('three', 3),
#  ('weeks', 3),
#  ('America', 3),
#  ('Spain', 3),
#  ('Igualada', 3),
#  ('Las Vegas', 3),
#  ('Congress', 3),
#  ('Singapore', 3),
#  ('N95', 3),
#  ('Afghanistan', 3)]

# %%
sentences=[x for x in webtext.sents]                                    #sentence tokenization
len_sent=len(sentences)                                                 #number of total sentence tokens
import random                                                           #generate random number k
k=round(random.random()*len_sent)
k
                                                                    #print 3 consecutive sentences
first_sent=sentences[k]
print(first_sent)
second_sent=sentences[k+1]
print(second_sent)
third_sent=sentences[k+2]
print(third_sent)
# Out:
# In Europe, Poland is using an app to track the movements of an estimated 10,000 people who are under home quarantine because they either tested positive for coronavirus or recently returned from abroad.
# Users are required to upload selfies several times a day to prove that they are following the rules of self-isolation, and any lapse in compliance results in an alert being sent to the police.
# In Croatia, rights groups are pushing back against proposed legislation to monitor cellphones, saying that it would be “an unnecessary violation of human rights.

# %%
d=str(first_sent)+ str(second_sent)+str(third_sent)                     #store all 3 consecutive snetences in one variable
d                                                                       #after converting them to string
# Out:
# 'In Europe, Poland is using an app to track the movements of an estimated 10,000 people who are under home quarantine because they either tested positive for coronavirus or recently returned from abroad.Users are required to upload selfies several times a day to prove that they are following the rules of self-isolation, and any lapse in compliance results in an alert being sent to the police.In Croatia, rights groups are pushing back against proposed legislation to monitor cellphones, saying that it would be “an unnecessary violation of human rights.'

# %%
doc = nlp(d)                                                #apply spacy function to all 3 sentences and store in variable
doc
# Out:
# In Europe, Poland is using an app to track the movements of an estimated 10,000 people who are under home quarantine because they either tested positive for coronavirus or recently returned from abroad.Users are required to upload selfies several times a day to prove that they are following the rules of self-isolation, and any lapse in compliance results in an alert being sent to the police.In Croatia, rights groups are pushing back against proposed legislation to monitor cellphones, saying that it would be “an unnecessary violation of human rights.

# %%
[(x.orth_ , x.pos_, x.lemma_)for x in [y                                #POS and Lemmatization of 3 consecutive sentences
                                      for y 
                                      in doc
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Europe', 'PROPN', 'Europe'),
#  ('Poland', 'PROPN', 'Poland'),
#  ('app', 'NOUN', 'app'),
#  ('track', 'VERB', 'track'),
#  ('movements', 'NOUN', 'movement'),
#  ('estimated', 'VERB', 'estimate'),
#  ('10,000', 'NUM', '10,000'),
#  ('people', 'NOUN', 'people'),
#  ('home', 'NOUN', 'home'),
#  ('quarantine', 'NOUN', 'quarantine'),
#  ('tested', 'VERB', 'test'),
#  ('positive', 'ADJ', 'positive'),
#  ('coronavirus', 'PROPN', 'coronavirus'),
#  ('recently', 'ADV', 'recently'),
#  ('returned', 'VERB', 'return'),
#  ('abroad', 'ADV', 'abroad'),
#  ('Users', 'NOUN', 'user'),
#  ('required', 'VERB', 'require'),
#  ('upload', 'VERB', 'upload'),
#  ('selfies', 'NOUN', 'selfie'),
#  ('times', 'NOUN', 'time'),
#  ('day', 'NOUN', 'day'),
#  ('prove', 'VERB', 'prove'),
#  ('following', 'VERB', 'follow'),
#  ('rules', 'NOUN', 'rule'),
#  ('self', 'NOUN', 'self'),
#  ('isolation', 'NOUN', 'isolation'),
#  ('lapse', 'NOUN', 'lapse'),
#  ('compliance', 'NOUN', 'compliance'),
#  ('results', 'NOUN', 'result'),
#  ('alert', 'NOUN', 'alert'),
#  ('sent', 'VERB', 'send'),
#  ('police', 'NOUN', 'police'),
#  ('Croatia', 'PROPN', 'Croatia'),
#  ('rights', 'NOUN', 'right'),
#  ('groups', 'NOUN', 'group'),
#  ('pushing', 'VERB', 'push'),
#  ('proposed', 'VERB', 'propose'),
#  ('legislation', 'NOUN', 'legislation'),
#  ('monitor', 'VERB', 'monitor'),
#  ('cellphones', 'NOUN', 'cellphone'),
#  ('saying', 'VERB', 'say'),
#  ('unnecessary', 'ADJ', 'unnecessary'),
#  ('violation', 'NOUN', 'violation'),
#  ('human', 'ADJ', 'human'),
#  ('rights', 'NOUN', 'right')]

# %%
from pprint import pprint

# %%
kth_sent=nlp(str(first_sent))
pprint([(x.text,x.label_)for x in kth_sent.ents])                                  #named entities for Kth(first) sentence
# Out:
# [('Europe', 'LOC'), ('Poland', 'GPE'), ('an estimated 10,000', 'CARDINAL')]

# %%
displacy.render(kth_sent,jupyter=True , style='ent')                            #visualize entities for Kth(first) sentence
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is using an app to track the movements of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an estimated 10,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people who are under home quarantine because they either tested positive for coronavirus or recently returned from abroad.</div></span>

# %%
displacy.render(kth_sent,jupyter=True , style='dep', options={'distance': 100})     #visualize dependencies for Kth sentence
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4c8943a5ec8f410890b24188e0df2a34-0" class="displacy" width="3350" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Europe,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Poland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">using</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">app</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">track</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">movements</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">estimated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">10,000</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">home</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">quarantine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">either</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">tested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">positive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">recently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">returned</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentC

# %%
displacy.render(webtext,jupyter=True , style='ent')                         # all entities in document
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">AdvertisementSupported byThe scientists leading the administration’s fight estimated the virus could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . New data suggests many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of infected people may not show symptoms.This briefing has ended. Read our global live coverage on the coronavirus pandemic here.The top government scientists battling the coronavirus estimated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that the deadly pathogen could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony S. Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the nation’s leading infectious disease expert, and Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deborah L. Birx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who is coordinating the coronavirus response, displayed that grim projection at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Birx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said the number of deaths could be much higher if
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  extended for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Birx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# .The data released on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesd

# %% [markdown]
# ## De-Identification ##

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc1 = nlp(mytext)

# %% [markdown]
# ### Functions to replace the PERSON entity with the word [REDACTED] in the document

# %%
def replace_per_name(token):
    if token.ent_iob !=0 and token.ent_type_=='PERSON':
        return '[REDACTED]'
    return token.string

# %%
def redact_name(nlp_doc):
    for ent in nlp_doc.ents:
        ent.merge()
        tokens=map(replace_per_name, nlp_doc)
        return ''.join(tokens)

# %%
redact= redact_name(doc1)
print(redact)
# Out:
# AdvertisementSupported byThe scientists leading the administration’s fight estimated the virus could kill between 100,000 and 240,000 Americans. New data suggests many as 25 percent of infected people may not show symptoms.This briefing has ended. Read our global live coverage on the coronavirus pandemic here.The top government scientists battling the coronavirus estimated Tuesday that the deadly pathogen could kill between 100,000 and 240,000 Americans, in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. [REDACTED][REDACTED][REDACTED], the nation’s leading infectious disease expert, and Dr. [REDACTED][REDACTED][REDACTED], who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. [REDACTED]and Dr. [REDACTED]said the number of deaths could be much higher if Americans do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President [REDACTED], who on Sunday extended for 30 days the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. [REDACTED]and Dr. [REDACTED]convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all Americans.The data released on Tuesday was the first time that Mr. [REDACTED]’s administration has officially estimated the breadth of the threat to human life from the coronavirus, and the disease it brings, known as Covid-19. In the past several weeks, Dr. [REDACTED]and Dr. [REDACTED]have resisted predicting how many people might die in the pandemic, saying that there was not enough reliable data.That is no longer the case, they said. As of Tuesday afternoon, at least 173,741 people across every state, plus Washington, D.C., and four U.S. territories, have tested positive for the virus, according to a New York Times database. At least 3,433 patients with the virus have died.transcript“I want every American to be prepared for the hard days that lie ahead. We’re going to go through a very tough two weeks, and then, hopefully, as the experts are predicting — as I think a lot of us are predicting after having studied it so hard — we’re going to start seeing some real light at the end of the tunnel. But this is going to be a very painful, very, very painful two weeks.” “When the increase in new cases begin to level off, the secondary effect is less hospitalizations. The next effect is less intensive care. And the next effect is less deaths. The deaths and the intensive care and the hospitalization always lag behind that early indication that there are less new cases per day. The way we saw in Italy, and the way we’re likely seeing — I don’t want to jump the gun on it. We’re seeing little inklings of this, right now, in New York. So what we’re going to see — and that is we’ve got to brace ourselves in the next several days to a week or so — we’re going to continue to see things go up. We cannot be discouraged by that because the mitigation is actually working and will work.” “So as you saw on that slide that was our real number — that 100,000 to 200,000, and we think that that is the range. We really believe and hope every day that we can do a lot better than that because that’s not assuming 100 percent of every American does everything that they’re supposed to be doing. But I think that’s possible.”President [REDACTED]said at his daily White House coronavirus briefing that “this is going to be a very painful, very very painful two weeks,” but that Americans will soon “start seeing some real light at the end of th ...

# %%
displacy.render(nlp(redact),jupyter=True , style='ent')                     #replace PERSON entity with REDACTED
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">AdvertisementSupported byThe scientists leading the administration’s fight estimated the virus could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . New data suggests many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of infected people may not show symptoms.This briefing has ended. Read our global live coverage on the coronavirus pandemic here.The top government scientists battling the coronavirus estimated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that the deadly pathogen could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. [REDACTED][REDACTED][REDACTED], the nation’s leading infectious disease expert, and Dr. [REDACTED][REDACTED][REDACTED], who is coordinating the coronavirus response, displayed that grim projection at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. [REDACTED]and Dr. [REDACTED]said the number of deaths could be much higher if
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President [REDACTED], who on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  extended for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. [REDACTED]and Dr. [REDACTED]convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# .The data released on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time that Mr. [REDACTED]’s administration has officially estimated the breadth of the threat to human life from the coronavirus, and the disease it brings, known as Covid-19. In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past several weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Dr. [REDACTED]and Dr. [REDACTED]have resisted predicting how many people might die in the pandemic, saying that there was not enough reliable data.That is no longer the case, they said. As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 173,741
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-le
